# %% [markdown]
# <a href="https://colab.research.google.com/github/da-head0/cctv-anomaly-detection/blob/main/2_anomaly_detection_cctv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### [Real-world Anomaly Detection in Surveillance Videos](https://www.crcv.ucf.edu/research/real-world-anomaly-detection-in-surveillance-videos/)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - 정상 / 이상 행동 학습을 통한 이상 탐지
# - 128 시간의 데이터셋 : 실제로는 1900개의 cctv 영상이었으나 이상 행동에 "폭행" "도로 사고" "강도" "도둑" 등으로 13개 라벨을 붙임.
# - 이전 연구들보다 이상 행동 탐지에서 뛰어난 성과를 보임 (2018년 기준)

# %% [markdown]
# - 정상/이상 행동 비디오를 나눠 사전 학습된 3D ConvNet을 사용, 32까지 노트를 줄이고(latent?) anomaly score로 노드를 1까지 줄이고(softmax 비슷한 듯) 각 라벨별 확률을 측정한 다음 가장 높은 스코어를 가진 라벨을 출력.

# %%
# !git clone https://github.com/WaqasSultani/AnomalyDetectionCVPR2018
# Out:
# Cloning into 'AnomalyDetectionCVPR2018'...
# remote: Enumerating objects: 152, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 152 (delta 0), reused 1 (delta 0), pack-reused 149
# Receiving objects: 100% (152/152), 10.73 MiB | 22.01 MiB/s, done.
# Resolving deltas: 100% (82/82), done.

# %%
# !pip install PyQt5
# Out:
# ERROR: Could not find a version that satisfies the requirement PyQt4 (from versions: none)
# ERROR: No matching distribution found for PyQt4

# %% [markdown]
# - model.json 파일에서 output dim -> units 로 바꿔줌

# %% [markdown]
# ### 깃허브에 올리기

# %%
# %cd /content/AnomalyDetectionCVPR2018
# Out:
# /content/AnomalyDetectionCVPR2018

# %%
# !git add .

# %%
# !git log

# %%
# !git commit -m "pyqt5 수정, 파이토치 버전 추가"
# Out:
# On branch master
# nothing to commit, working tree clean

# %%
# !git config --global user.email "andyourturntome@gmail.com"
# !git config --global user.name "da-head0"

# %%
# !git remote -v
# Out:
# origin	https://github.com/da-head0/AnomalyDetectionCVPR2018 (fetch)
# origin	https://github.com/da-head0/AnomalyDetectionCVPR2018 (push)

# %%
# !git remote remove origin

# %%
# !git remote add origin https://github.com/da-head0/AnomalyDetectionCVPR2018

# %%
# !git push --set-upstream origin master
# Out:
# fatal: could not read Username for 'https://github.com': No such device or address

# %% [markdown]
# ### 코드 돌려보기

# %%
# Demo.gui에서 pyqt4 -> pyqt5로 바꿔줌
# 158줄         video_path, _ = QtGui.QFileDialog.getOpenFileName(self,

# %%
# !python Demo_GUI.py # 샘플 비디오에 대한 결과
#!python Test_Anomaly_Detector_public.py
# Out:
# 2021-05-06 15:44:57.397095: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# qt.qpa.xcb: could not connect to display
# qt.qpa.plugin: Could not load the Qt platform plugin "xcb" in "" even though it was found.
# This application failed to start because no Qt platform plugin could be initialized. Reinstalling the application may fix this problem.
#
# Available platform plugins are: eglfs, linuxfb, minimal, minimalegl, offscreen, vnc, wayland-egl, wayland, wayland-xcomposite-egl, wayland-xcomposite-glx, webgl, xcb.

# %% [markdown]
# Temporal_Anomaly_Annotation.txt
#
# 오.... 이거 되겠는데? 파일 이름, 유형, 시작, 끝, -1 -1은 뭐지?
# 한번 더 있을 경우? -1 -1은 정상인듯

# %%
# %cd ..
# Out:
# /content

# %%
# !git clone https://github.com/ekosman/AnomalyDetectionCVPR2018-Pytorch.git
# Out:
# Cloning into 'AnomalyDetectionCVPR2018-Pytorch'...
# remote: Enumerating objects: 787, done.
# remote: Counting objects: 100% (193/193), done.
# remote: Compressing objects: 100% (149/149), done.
# remote: Total 787 (delta 96), reused 117 (delta 43), pack-reused 594
# Receiving objects: 100% (787/787), 161.56 MiB | 33.40 MiB/s, done.
# Resolving deltas: 100% (449/449), done.

# %%
# %cd AnomalyDetectionCVPR2018-Pytorch
# Out:
# /content/AnomalyDetectionCVPR2018-Pytorch

# %% [markdown]
# - Annotation

# %%
python annotation_methods.py --path_list LIST_OF_VIDEO_PATH --dir_list LIST_OF_LIST_WITH_PATH_AND_VIDEO_NAME --normal_or_not LIST_TRUE_FALUE

# %%
python video_demo.py --feature_extractor "path-to-pretrained-fe" --feature_method "fe-method" --ad_model "path-to-pretrained-ad-model" --n_segments "number-of-segments"
